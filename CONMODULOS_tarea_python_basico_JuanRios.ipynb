# %%
import random
import openpyxl
import matplotlib.pyplot as grafico
from getpass import getpass

# %%
import jd_mod_excel
import jd_mod_utiles
import jd_mod_juego
import jd_mod_main
import jd_mod_main

# %%
jd_mod_main.adivinaElNumero()
# Out:
# elija entre las siguientes opciones, introduzca sólo el número
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# 3
# introduce de qué jugador quieres las estadísticas: RT
# jugador no encontrado
#
# elija entre las siguientes opciones, introduzca sólo el número
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# 1
# elija entre las siguientes opciones, introduzca sólo el número
# 1. Fácil (20 intentos, rango de números posibles [1,100])
# 2. Medio (12 intentos, rango de números posibles [1,500])
# 3. Difícil (5 intentos, rango de números posibles [1,1000])
# 2
# Jugador 1, debes acertar el número que la máquina elija
# jugador1 elige un número: 3
# el número buscado era mayor
#
# jugador1 elige un número: 3
# el número buscado era mayor
#
# jugador1 elige un número: 3
# el número buscado era mayor
#
# jugador1 elige un número: 3
# el número buscado era mayor
#
# jugador1 elige un número: 3
# el número buscado era mayor
# ...

# %%
jd_mod_excel.estadistica_borrar()
